# %% [markdown]
# <a href="https://colab.research.google.com/github/data602sps/datasetspractice/blob/main/07_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment 6**
#
# # **Weeks 8 & 9 - Pandas**
# * In this homework assignment, you will explore and analyze a public dataset of your choosing. Since this assignment is “open-ended” in nature, you are free to expand upon the requirements below. However, you must meet the minimum requirments as indicated in each section.
#
# * You must use Pandas as the **primary tool** to process your data.
#
# * The preferred method for this analysis is in a .ipynb file. Feel free to use whichever platform of your choosing.
#  * https://www.youtube.com/watch?v=inN8seMm7UI (Getting started with Colab).
#
# * Your data should need some "work", or be considered "dirty".  You must show your skills in data cleaning/wrangling.
#
# ### **Some data examples:**
# •	https://www.data.gov/
#
# •	https://opendata.cityofnewyork.us/
#
# •	https://datasetsearch.research.google.com/
#
# •	https://archive.ics.uci.edu/ml/index.php
#
# ### **Resources:**
#
# •	https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
#
# •	https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#
#
# ### **Headings or comments**
# **You are required to make use of comments, or headings for each section.  You must explain what your code is doing, and the results of running your code.**  Act as if you were giving this assignment to your manager - you must include clear and descriptive information for each section.
#
# ### **You may work as a group or indivdually on this assignment.**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Introduction
#
# In this section, please describe the dataset you are using.  Include a link to the source of this data.  You should also provide some explanation on why you choose this dataset.

# %% [markdown]
# ### Load all 4 datasets
#
# 1. Kobe dataset in honor of a great player. I also thought the data would be iteresting to look at
# 2. Google dataset. I choose because of the timeseries nature. Changes would be a bit different than other datasets, starting by by adding timestamp index
# 3. Wine data. I love wine. This is a popular dataset in machine learning
# 4. Drug use by age.  Small dataset but I was really curious on drug usage by age. I thought it would have interesting facts which may come usefull at a christmas conversation.

# %%
url1 = 'https://raw.githubusercontent.com/data602sps/datasetspractice/main/kobe.csv'
url2 = 'https://raw.githubusercontent.com/data602sps/datasetspractice/main/GOOG.csv'
url3 = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'
url4 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/drug-use-by-age/drug-use-by-age.csv'

df1 = pd.read_csv(url1)
df2 = pd.read_csv(url2)
df3 = pd.read_csv(url3)
df4 = pd.read_csv(url4)

# %% [markdown]
# ### Basic check if data loaded correctly from source

# %%
# Lets list first rows of the loaded dataset
df1.head()
# Out:
#     vs  game quarter  time                                        description  \
# 0  ORL     1       1  9:47            Kobe Bryant makes 4-foot two point shot
# 1  ORL     1       1  9:07                          Kobe Bryant misses jumper
# 2  ORL     1       1  8:11                   Kobe Bryant misses 7-foot jumper
# 3  ORL     1       1  7:41  Kobe Bryant makes 16-foot jumper (Derek Fisher...
# 4  ORL     1       1  7:03                    Kobe Bryant makes driving layup
#
#   basket
# 0      H
# 1      M
# 2      M
# 3      H
# 4      H

# %%
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 1  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 2  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 3  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 4  2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
#
#     Volume
# 0  2213200
# 1  1974700
# 2  1746700
# 3  2243000
# 4  1317300

# %%
df3.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
df4.head()
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
#
#    marijuana-frequency  cocaine-use cocaine-frequency  crack-use  \
# 0                  4.0          0.1               5.0        0.0
# 1                 15.0          0.1               1.0        0.0
# 2                 24.0          0.1               5.5        0.0
# 3                 25.0          0.5               4.0        0.1
# 4                 30.0          1.0               7.0        0.0
#
#   crack-frequency  ...  oxycontin-use oxycontin-frequency  tranquilizer-use  \
# 0               -  ...            0.1                24.5               0.2
# ...

# %%
# All four datasets are loaded and ready to be processed

# %% [markdown]
# # Dataset 1 - KOBE Dataset

# %% [markdown]
# ______________
# # Data Exploration
# Import your dataset into your .ipynb, create dataframes, and explore your data.
#
# Include:
#
# * Summary statistics means, medians, quartiles,
# * Missing value information
# * Any other relevant information about the dataset.

# %%
# Basic shape of our dataset
df1.shape
# 133 rows, 6 columns
# Out:
# (133, 6)

# %%
# We will check the datatypes of each column
df1.dtypes
# game is an intereger
# all other are object datatype which include strings
# Out:
# vs             object
# game            int64
# quarter        object
# time           object
# description    object
# basket         object
# dtype: object

# %%
# Some basic stats of the dataset numeric field
df1.describe()
# mean is 2.9 and max 5, with a mean of 1
# Out:
#              game
# count  133.000000
# mean     2.902256
# std      1.450521
# min      1.000000
# 25%      1.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000

# %%
# Another variance of basic information for a dataset.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   vs           133 non-null    object
#  1   game         133 non-null    int64
#  2   quarter      133 non-null    object
#  3   time         133 non-null    object
#  4   description  133 non-null    object
#  5   basket       133 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 6.4+ KB

# %% [markdown]
# # Data Wrangling
# Create a subset of your original data and perform the following.
#
# 1. Modify multiple column names.
#
# 2. Look at the structure of your data – are any variables improperly coded? Such as strings or characters? Convert to correct structure if needed.
#
# 3. Fix missing and invalid values in data.
#
# 4. Create new columns based on existing columns or calculations.
#
# 5. Drop column(s) from your dataset.
#
# 6. Drop a row(s) from your dataset.
#
# 7. Sort your data based on multiple variables.
#
# 8. Filter your data based on some condition.
#
# 9. Convert all the string values to upper or lower cases in one column.
#
# 10. Check whether numeric values are present in a given column of your dataframe.
#
# 11. Group your dataset by one column, and get the mean, min, and max values by group.
#   * Groupby()
#   * agg() or .apply()
#
# 12. Group your dataset by two columns and then sort the aggregated results within the groups.
#
# **You are free (and should) to add on to these questions.  Please clearly indicate in your assignment your answers to these questions.**

# %%
#Check for any missing values
df1.isnull().sum()
# Out:
# vs             0
# game           0
# quarter        0
# time           0
# description    0
# basket         0
# dtype: int64

# %%
# We will rename column vs to "opponent" to make it clear
df1.rename(columns={'vs': 'opponent'}, inplace=True)
df1.head()
# Out:
#   opponent  game quarter  time  \
# 0      ORL     1       1  9:47
# 1      ORL     1       1  9:07
# 2      ORL     1       1  8:11
# 3      ORL     1       1  7:41
# 4      ORL     1       1  7:03
#
#                                          description basket
# 0            Kobe Bryant makes 4-foot two point shot      H
# 1                          Kobe Bryant misses jumper      M
# 2                   Kobe Bryant misses 7-foot jumper      M
# 3  Kobe Bryant makes 16-foot jumper (Derek Fisher...      H
# 4                    Kobe Bryant makes driving layup      H

# %%
# We will change basket from string to boolean just because we can
d = {'H': True, 'M': False}
df1['basket'] = df1['basket'].map(d)
df1.head()
# Out:
#   opponent  game quarter  time  \
# 0      ORL     1       1  9:47
# 1      ORL     1       1  9:07
# 2      ORL     1       1  8:11
# 3      ORL     1       1  7:41
# 4      ORL     1       1  7:03
#
#                                          description  basket
# 0            Kobe Bryant makes 4-foot two point shot    True
# 1                          Kobe Bryant misses jumper   False
# 2                   Kobe Bryant misses 7-foot jumper   False
# 3  Kobe Bryant makes 16-foot jumper (Derek Fisher...    True
# 4                    Kobe Bryant makes driving layup    True

# %%
# Create a new column based on existing columns
df1["Opponent_Full"] = np.where(df1['opponent']== 'ORL', "Orlando", "Other")
df1.head()
# Out:
#   opponent  game quarter  time  \
# 0      ORL     1       1  9:47
# 1      ORL     1       1  9:07
# 2      ORL     1       1  8:11
# 3      ORL     1       1  7:41
# 4      ORL     1       1  7:03
#
#                                          description  basket Opponent_Full
# 0            Kobe Bryant makes 4-foot two point shot    True       Orlando
# 1                          Kobe Bryant misses jumper   False       Orlando
# 2                   Kobe Bryant misses 7-foot jumper   False       Orlando
# 3  Kobe Bryant makes 16-foot jumper (Derek Fisher...    True       Orlando
# 4                    Kobe Bryant makes driving layup    True       Orlando

# %%
#Drop a column
df1.drop(['time'], axis=1, inplace=True)
df1.head()
# Out:
#   opponent  game quarter                                        description  \
# 0      ORL     1       1            Kobe Bryant makes 4-foot two point shot
# 1      ORL     1       1                          Kobe Bryant misses jumper
# 2      ORL     1       1                   Kobe Bryant misses 7-foot jumper
# 3      ORL     1       1  Kobe Bryant makes 16-foot jumper (Derek Fisher...
# 4      ORL     1       1                    Kobe Bryant makes driving layup
#
#    basket Opponent_Full
# 0    True       Orlando
# 1   False       Orlando
# 2   False       Orlando
# 3    True       Orlando
# 4    True       Orlando

# %%
#delete some rows
df1 = df1.drop(labels=[0,2,4], axis=0)
df1.head()
# Out:
#   opponent  game quarter                                        description  \
# 1      ORL     1       1                          Kobe Bryant misses jumper
# 3      ORL     1       1  Kobe Bryant makes 16-foot jumper (Derek Fisher...
# 5      ORL     1       1                          Kobe Bryant misses jumper
# 6      ORL     1       1                  Kobe Bryant misses 12-foot jumper
# 7      ORL     1       1                  Kobe Bryant misses 19-foot jumper
#
#    basket Opponent_Full
# 1   False       Orlando
# 3    True       Orlando
# 5   False       Orlando
# 6   False       Orlando
# 7   False       Orlando

# %%
# Sort dataframe on several feature
df1 = df1.sort_values(by=['game','quarter'], 
                          ascending=[True, False])
df1.head()
# Out:
#    opponent  game quarter                        description  basket  \
# 29      ORL     1       4  Kobe Bryant misses 15-foot jumper   False
# 30      ORL     1       4  Kobe Bryant misses 11-foot jumper   False
# 31      ORL     1       4           Kobe Bryant misses layup   False
# 32      ORL     1       4  Kobe Bryant misses 13-foot jumper   False
# 33      ORL     1       4   Kobe Bryant makes 10-foot jumper    True
#
#    Opponent_Full
# 29       Orlando
# 30       Orlando
# 31       Orlando
# 32       Orlando
# 33       Orlando

# %%
#Filter your data based on some condition.
df1b = df1[df1["basket"]==True]
df1b.head()
# Out:
#    opponent  game quarter                               description  basket  \
# 33      ORL     1       4          Kobe Bryant makes 10-foot jumper    True
# 18      ORL     1       3                   Kobe Bryant makes layup    True
# 19      ORL     1       3  Kobe Bryant makes 11-foot two point shot    True
# 22      ORL     1       3  Kobe Bryant makes 14-foot two point shot    True
# 24      ORL     1       3          Kobe Bryant makes two point shot    True
#
#    Opponent_Full
# 33       Orlando
# 18       Orlando
# 19       Orlando
# 22       Orlando
# 24       Orlando

# %%
#Convert String values to upper case
df1['Opponent_Full'] = df1['Opponent_Full'].str.upper()
df1.head()
# Out:
#    opponent  game quarter                        description  basket  \
# 29      ORL     1       4  Kobe Bryant misses 15-foot jumper   False
# 30      ORL     1       4  Kobe Bryant misses 11-foot jumper   False
# 31      ORL     1       4           Kobe Bryant misses layup   False
# 32      ORL     1       4  Kobe Bryant misses 13-foot jumper   False
# 33      ORL     1       4   Kobe Bryant makes 10-foot jumper    True
#
#    Opponent_Full
# 29       ORLANDO
# 30       ORLANDO
# 31       ORLANDO
# 32       ORLANDO
# 33       ORLANDO

# %%
#Check whether a column is numeric
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

print(is_numeric_dtype(df1['quarter']))
print(is_numeric_dtype(df1['game']))
# Out:
# False
# True

# %%
#Group your dataset by one column, and get the mean, min, and max values by group
result = df1.groupby('game').agg({'basket': ['mean', 'min', 'max', 'sum']})
  
print("Mean, min, and max values of Top Speed grouped by Vehicle Type")
print(result)
# Out:
# Mean, min, and max values of Top Speed grouped by Vehicle Type
#         basket
#           mean    min   max sum
# game
# 1     0.451613  False  True  14
# 2     0.476190  False  True  10
# 3     0.440000  False  True  11
# 4     0.366667  False  True  11
# 5     0.434783  False  True  10

# %%
# Group your dataset by two columns and then sort the aggregated results within the groups.
baskets = df1.groupby(["game","quarter"]).agg({'basket':sum})
baskets.sort_values(by=['game','quarter'],ascending=[True, True])
# Out:
#               basket
# game quarter
# 1    1             1
#      2             6
#      3             6
#      4             1
# 2    1             1
#      1OT           1
#      2             1
#      3             5
#      4             2
# 3    1             7
#      2             1
#      3             1
#      4             2
# 4    1             4
#      1OT           2
#      2             1
#      3             2
#      4             2
# 5    1             3
#      2             2
#      3             2
#      4             3

# %% [markdown]
# # Conclusions
#
# After exploring your dataset, provide a short summary of what you noticed from this dataset.  What would you explore further with more time?

# %% [markdown]
# #### We can see that in this series besides a few quarters where Kobe scored 6 or 7 times in the quarter,
# #### most quarters Kobe's performance was more balanced, yet keeping his scoring between.
# #### 10 to 14 times per game

# %% [markdown]
# # Dataset 2 - Google Dataset

# %%
# lets list the first rows in the dataset
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 1  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 2  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 3  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 4  2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
#
#     Volume
# 0  2213200
# 1  1974700
# 2  1746700
# 3  2243000
# 4  1317300

# %%
# We can see the dataset has 1258 rows and 7 columns mostly numerical
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
#  6   Volume     1258 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %%
# Descriptive statistics in this timeseries don't seem to provide valuable information
df2.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    842.065785   849.196733   834.607101   842.175733   842.175733
# std     224.688021   227.042283   222.565409   224.969453   224.969453
# min     491.942810   493.261566   484.891632   489.854309   489.854309
# 25%     645.425003   650.681763   637.150024   643.905029   643.905029
# 50%     795.364990   801.023010   790.855011   795.359985   795.359985
# 75%    1051.584992  1064.093719  1040.893494  1052.059967  1052.059967
# max    1274.000000  1289.270020  1266.295044  1287.579956  1287.579956
#
#              Volume
# count  1.258000e+03
# mean   1.750196e+06
# std    8.586929e+05
# min    5.272000e+05
# 25%    1.243325e+06
# 50%    1.531050e+06
# 75%    1.995025e+06
# max    1.116490e+07

# %%
#For timeseries let's plot, it will give us a better sense of the data
df2['Close'].plot()
# Out:
# <AxesSubplot:>

# %%
#For a times series is better to convert the date string to datetime type
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df2.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
#lets change the index to the datetime column. This will allow to some interesting things with the
# dataset syarting with Plotting
df2 = df2.set_index('Date')
df2.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
#
#              Volume
# Date
# 2014-06-24  2213200
# 2014-06-25  1974700
# 2014-06-26  1746700
# 2014-06-27  2243000
# 2014-06-30  1317300

# %%
# The plot now chows the dates in the x-axis
df2["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#We will add a new column that indicate the percentage change in a day
df2["change"] = (df2["Close"]/df2["Open"] -1)*100

# %%
# Lets sort by daily price change to see the dates of the biggest
# one day increase and decreases.

df2_sorted = df2.sort_values(by=["change"], ascending=[False])
print(df2_sorted['change'].head())
print(df2_sorted['change'].tail())
# Out:
# Date
# 2018-02-06    5.200639
# 2018-12-26    5.101056
# 2019-05-15    4.145381
# 2019-01-04    3.691688
# 2015-07-17    3.687210
# Name: change, dtype: float64
# Date
# 2018-02-08   -5.106074
# 2015-08-25   -5.342241
# 2018-03-27   -5.446851
# 2016-02-03   -5.617870
# 2018-10-29   -5.763666
# Name: change, dtype: float64

# %% [markdown]
# ## Dataset 3 - Wine Data

# %%
#Lets take a look at the firs 5 rows in the dataset
df3.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
# The dataset doesn't have column names, so let's add them

# %%
df3.columns = ["wine_class","alcohol","malic_acid","ash","alcalinity","magnesium","phenols","flavanoids",
               "non_flavanoids","proanthocyanins","color_instensity","hue","OD280_315","proline"]
df3.head()
# Out:
#    wine_class  alcohol  malic_acid   ash  alcalinity  magnesium  phenols  \
# 0           1    13.20        1.78  2.14        11.2        100     2.65
# 1           1    13.16        2.36  2.67        18.6        101     2.80
# 2           1    14.37        1.95  2.50        16.8        113     3.85
# 3           1    13.24        2.59  2.87        21.0        118     2.80
# 4           1    14.20        1.76  2.45        15.2        112     3.27
#
#    flavanoids  non_flavanoids  proanthocyanins  color_instensity   hue  \
# 0        2.76            0.26             1.28              4.38  1.05
# 1        3.24            0.30             2.81              5.68  1.03
# 2        3.49            0.24             2.18              7.80  0.86
# 3        2.69            0.39             1.82              4.32  1.04
# 4        3.39            0.34             1.97              6.75  1.05
#
#    OD280_315  proline
# 0       3.40     1050
# 1       3.17     1185
# 2       3.45     1480
# ...

# %%
#Very numeric dataset. Interesting set for doing some Machine Learning.
# Only 177 rows but with 14 columns all numeric. makes it a nice set to test some PCA.
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   wine_class        177 non-null    int64
#  1   alcohol           177 non-null    float64
#  2   malic_acid        177 non-null    float64
#  3   ash               177 non-null    float64
#  4   alcalinity        177 non-null    float64
#  5   magnesium         177 non-null    int64
#  6   phenols           177 non-null    float64
#  7   flavanoids        177 non-null    float64
#  8   non_flavanoids    177 non-null    float64
#  9   proanthocyanins   177 non-null    float64
#  10  color_instensity  177 non-null    float64
#  11  hue               177 non-null    float64
#  12  OD280_315         177 non-null    float64
#  13  proline           177 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.5 KB

# %%
#We will do something interesting with the data and do ML.  We will reduce dimensions using PCA (Principal
# Component Analysis) this will allow us to plot using two dimension and see if we see some common
# groupings on the different wine classes based on their respective
# attributes

# %%
#We will separate the data into two tables. One only with the row's wine class and
# another table will all the numeric data
df3_data = df3.iloc[:,1:]
df3_classes = df3["wine_class"]

# %%
# We will scikit-learn to do PCA.
#First will standardize the data to perform PCA.

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df3_data)
scaled_data = scaler.transform(df3_data)

# %%
# Here we tell sklearn to reduce the datasset to 2 Principal components
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)

# %%
#Let's plot the data, now reduced to only two dimensions and colore it based on its wine class
#and see if we see any common grouping (Clustering)
from matplotlib import pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=df3_classes,cmap='rainbow')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
# We can clearly see that the 3 wine classes are nicely clustered in three distinct groups
# based on its reduced dimension (Principal Components)

# %%
import seaborn as sns

# %%
#Here we will plot the Principal components and its
#corelation to each Column in the original dataset

col_names =  ["alcohol","malic_acid","ash","alcalinity","magnesium","phenols","flavanoids",
               "non_flavanoids","proanthocyanins","color_instensity","hue","OD280_315","proline"]
map= pd.DataFrame(pca.components_,columns=col_names)
plt.figure(figsize=(12,6))
sns.heatmap(map,cmap='bwr')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Dataset 4 - Drug Use by Age

# %%
df4.head()
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
#
#    marijuana-frequency  cocaine-use cocaine-frequency  crack-use  \
# 0                  4.0          0.1               5.0        0.0
# 1                 15.0          0.1               1.0        0.0
# 2                 24.0          0.1               5.5        0.0
# 3                 25.0          0.5               4.0        0.1
# 4                 30.0          1.0               7.0        0.0
#
#   crack-frequency  ...  oxycontin-use oxycontin-frequency  tranquilizer-use  \
# 0               -  ...            0.1                24.5               0.2
# ...

# %%
df4
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# ...

# %%
# Not a very large datasert. Only 17 rows, but with 28 columns
# it has some interesting data to review
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      17 non-null     object
#  1   n                        17 non-null     int64
#  2   alcohol-use              17 non-null     float64
#  3   alcohol-frequency        17 non-null     float64
#  4   marijuana-use            17 non-null     float64
#  5   marijuana-frequency      17 non-null     float64
#  6   cocaine-use              17 non-null     float64
#  7   cocaine-frequency        17 non-null     object
#  8   crack-use                17 non-null     float64
#  9   crack-frequency          17 non-null     object
#  10  heroin-use               17 non-null     float64
#  11  heroin-frequency         17 non-null     object
#  12  hallucinogen-use         17 non-null     float64
#  13  hallucinogen-frequency   17 non-null     float64
# ...

# %%
# Lets plot Cocaine-Use by age
x=list(range(0,17))
plt.xticks(x, df4["age"], rotation ='vertical')
plt.plot(df4["cocaine-use"])

# %%
# Let's compare it with Alcohol use
x=list(range(0,17))
plt.xticks(x, df4["age"], rotation ='vertical')
plt.plot(df4["alcohol-use"])

# %%
# We can clearly see that peak drug usage is around 21 years of age
# between 12 to 21-23 grud usage is almost linear increasing
# After that drug usage start decreasing.  Alcohol much slower decrease than Cocaine
